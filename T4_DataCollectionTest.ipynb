# %% [markdown]
# # Python Script to Download test Posters

# %%
import pandas as pd
import requests
import os
import re
import time
from tqdm import tqdm

# Load TEST dataset instead of train
df = pd.read_csv('movies_test.csv')  # CAMBIO AQUÍ
os.makedirs('posters_test', exist_ok=True)  # CAMBIO AQUÍ: carpeta diferente

API_KEY = '5530ad51b9026b431326f51af1a07d3a'

def poster_exists(movie_id):
    return os.path.exists(f"posters_test/{movie_id}.jpg")  # CAMBIO AQUÍ

def get_movie_poster(title, movie_id):
    if poster_exists(movie_id):
        return True
    
    clean_title = re.sub(r'\s*\(\d{4}\)', '', title).strip()
    
    try:
        search_url = "https://api.themoviedb.org/3/search/movie"
        params = {'api_key': API_KEY, 'query': clean_title}
        response = requests.get(search_url, params=params, timeout=10)
        
        if response.status_code == 200:
            results = response.json()['results']
            if results:
                poster_path = results[0].get('poster_path')
                if poster_path:
                    poster_url = f"https://image.tmdb.org/t/p/w500{poster_path}"
                    poster_response = requests.get(poster_url, timeout=10)
                    
                    if poster_response.status_code == 200:
                        with open(f"posters_test/{movie_id}.jpg", 'wb') as f:  # CAMBIO AQUÍ
                            f.write(poster_response.content)
                        print(f"✓ Downloaded: {title}")
                        return True
                    else:
                        print(f"✗ Download failed: {title}")
                else:
                    print(f"✗ No poster: {title}")
            else:
                print(f"✗ Not found: {title}")
        else:
            print(f"✗ API error: {title}")
    except Exception as e:
        print(f"✗ Error: {title} - {str(e)}")
    
    return False

# Download only missing posters
print("Downloading TEST posters...")  # CAMBIO AQUÍ
existing = sum(1 for mid in df['movieId'] if poster_exists(mid))
success = existing

for _, row in tqdm(df.iterrows(), total=len(df)):
    if not poster_exists(row['movieId']):
        if get_movie_poster(row['title'], row['movieId']):
            success += 1
        time.sleep(0.1)

print(f"\nFinal: {success}/{len(df)} TEST posters downloaded")  # CAMBIO AQUÍ
# Out:
# ...
#   0%|          | 1/2923 [00:04<3:45:00,  4.62s/it]
# ✓ Downloaded: Notorious Bettie Page, The (2005)
#   0%|          | 2/2923 [00:06<2:38:05,  3.25s/it]
# ✓ Downloaded: Star Trek V: The Final Frontier (1989)
#   0%|          | 3/2923 [00:09<2:26:35,  3.01s/it]
# ✓ Downloaded: Starsky & Hutch (2004)
#   0%|          | 4/2923 [00:12<2:19:52,  2.88s/it]
# ✓ Downloaded: Colonel Chabert, Le (1994)
#   0%|          | 5/2923 [00:14<2:09:48,  2.67s/it]
# ✓ Downloaded: Country Girl, The (1954)
#   0%|          | 6/2923 [00:16<2:03:30,  2.54s/it]
# ✓ Downloaded: Civil War, The (1990)
#   0%|          | 7/2923 [00:20<2:26:51,  3.02s/it]
# ✓ Downloaded: John Mulaney: New In Town (2012)
#   0%|          | 8/2923 [00:23<2:24:48,  2.98s/it]
# ✓ Downloaded: Saving Christmas (2014)
#   0%|          | 9/2923 [00:26<2:24:29,  2.98s/it]
# ✓ Downloaded: Kolya (Kolja) (1996)
#   0%|          | 10/2923 [00:30<2:31:45,  3.13s/it]
# ✓ Downloaded: Alice in Wonderland (2010)
# ...

# %% [markdown]
# # Delete missed posters

# %%
import pandas as pd
import os

# Cargar el dataset de test
df = pd.read_csv('movies_test.csv')

# Filtrar solo los movieId que tienen poster
df = df[df['movieId'].apply(lambda x: os.path.exists(f'posters_test/{x}.jpg'))]

# Guardar en el mismo archivo (sobrescribir)
df.to_csv('movies_test.csv', index=False)

print(f"Películas con poster: {len(df)}")
print("Archivo movies_test.csv actualizado")
# Out:
# Películas con poster: 1497
# Archivo movies_test.csv actualizado
